# %%
from env.res_env_evil import ResistanceEvilEnv
from env.res_env import ResistanceEnv

import numpy as np
import os
from utils.buffer import SharedReplayBuffer
import numpy as np
from runner.runner_res_evil_trainer import RunnerMA_Evil
from runner.runner_res import RunnerMA

from alg.actor_critic import Actor, Critic

# %%
### Restore Good policy

# %%
# Example configuration
class Args:
    def __init__(self):
        self.env_name = 'Resistance Evil Env'
        self.algorithm_name = 'MAPPO'
        self.experiment_name = 'Res Experience'
        self.use_centralized_V = True
        self.num_env_steps = 7
        self.episode_length = 7
        self.n_rollout_threads = 1
        self.use_linear_lr_decay = False
        self.hidden_size = 64
        self.gamma = .99
        self.gae_lambda = .95
        self._use_gae = True
        self.actor_lr = 7e-4
        self.critic_lr = 1e-3
        self.opti_eps=1e-5
        self.weight_decay=0
        self.gamma=0.99
        self.clip_param=0.2
        self.value_loss_coef=1
        self.entropy_coef=0.01
        self.ppo_epoch=10
        self.num_mini_batch=1
        self.huber_delta=10.0
        self.use_huber_loss=True
        self.use_clipped_value_loss=True
        self.gain = 0.01
        self.use_orthogonal = True
        self.use_feature_normalization = True
        self.use_ReLU = True
        self.layer_N = 1
        self.log_interval = 1000  # log every x steps
        
env = ResistanceEnv()

config = {
    'all_args': Args(),
    'env': env,
    'device': 'cpu',
    'num_agents': 1,
}
runner_good = RunnerMA(config)
runner_good.restore('save_dir')
good_policy = runner_good.trainer.policy

# %%
### Set Up

# %%
# Example configuration
class Args:
    def __init__(self):
        self.env_name = 'Resistance Evil Env'
        self.algorithm_name = 'MAPPO'
        self.experiment_name = 'Res Experience'
        self.use_centralized_V = True
        self.num_env_steps = 7
        self.episode_length = 7
        self.n_rollout_threads = 1
        self.use_linear_lr_decay = False
        self.hidden_size = 64
        self.gamma = .99
        self.gae_lambda = .95
        self._use_gae = True
        self.actor_lr = 7e-4
        self.critic_lr = 1e-3
        self.opti_eps=1e-5
        self.weight_decay=0
        self.gamma=0.99
        self.clip_param=0.2
        self.value_loss_coef=1
        self.entropy_coef=0.01
        self.ppo_epoch=10
        self.num_mini_batch=1
        self.huber_delta=10.0
        self.use_huber_loss=True
        self.use_clipped_value_loss=True
        self.gain = 0.01
        self.use_orthogonal = True
        self.use_feature_normalization = True
        self.use_ReLU = True
        self.layer_N = 1
        self.log_interval = 1000  # log every x steps
        
env = ResistanceEvilEnv()

config = {
    'all_args': Args(),
    'env': env,
    'device': 'cpu',
    'num_agents': 2,
    'good_policy': good_policy
}
runner = RunnerMA_Evil(config)

# %%
runner.warmup()

# %%
runner.run(verbose=False)

# %%
runner.eval(100, verbose=False)
# Out:
# Episode 1: Reward = 18, Number of steps: 28
# =======  EPISODE END  ================
#
# Episode 2: Reward = -16, Number of steps: 27
# =======  EPISODE END  ================
#
# Episode 3: Reward = -18, Number of steps: 36
# =======  EPISODE END  ================
#
# Episode 4: Reward = -16, Number of steps: 19
# =======  EPISODE END  ================
#
# Episode 5: Reward = -16, Number of steps: 23
# =======  EPISODE END  ================
#
# Episode 6: Reward = -16, Number of steps: 31
# =======  EPISODE END  ================
#
# Episode 7: Reward = 18, Number of steps: 33
# =======  EPISODE END  ================
#
# Episode 8: Reward = -16, Number of steps: 27
# =======  EPISODE END  ================
#
# Episode 9: Reward = -16, Number of steps: 19
# =======  EPISODE END  ================
#
# Episode 10: Reward = -18, Number of steps: 30
# =======  EPISODE END  ================
#
# Episode 11: Reward = -20, Number of steps: 35
# =======  EPISODE END  ================
#
# Episode 12: Reward = -16, Number of steps: 19
# =======  EPISODE END  ================
#
# Episode 13: Reward = -16, Number of steps: 17
# =======  EPISODE END  ================
#
# Episode 14: Reward = -18, Number of steps: 40
# =======  EPISODE END  ================
#
# Episode 15: Reward = -16, Number of steps: 25
# =======  EPISODE END  ================
#
# Episode 16: Reward = -16, Number of steps: 17
# =======  EPISODE END  ================
#
# Episode 17: Reward = -16, Number of steps: 21
# =======  EPISODE END  ================
#
# Episode 18: Reward = -16, Number of steps: 25
# =======  EPISODE END  ================
#
# Episode 19: Reward = -18, Number of steps: 24
# =======  EPISODE END  ================
#
# Episode 20: Reward = -16, Number of steps: 29
# =======  EPISODE END  ================
#
# Episode 21: Reward = -16, Number of steps: 19
# =======  EPISODE END  ================
#
# Episode 22: Reward = -20, Number of steps: 29
# =======  EPISODE END  ================
#
# Episode 23: Reward = 22, Number of steps: 27
# =======  EPISODE END  ================
#
# Episode 24: Reward = -18, Number of steps: 40
# =======  EPISODE END  ================
#
# Episode 25: Reward = -18, Number of steps: 32
# =======  EPISODE END  ================
#
# Episode 26: Reward = -16, Number of steps: 21
# =======  EPISODE END  ================
#
# Episode 27: Reward = -16, Number of steps: 15
# =======  EPISODE END  ================
#
# Episode 28: Reward = -16, Number of steps: 21
# =======  EPISODE END  ================
#
# Episode 29: Reward = 20, Number of steps: 35
# =======  EPISODE END  ================
#
# Episode 30: Reward = 20, Number of steps: 33
# =======  EPISODE END  ================
#
# Episode 31: Reward = 22, Number of steps: 27
# =======  EPISODE END  ================
#
# Episode 32: Reward = -18, Number of steps: 34
# =======  EPISODE END  ================
#
# Episode 33: Reward = -16, Number of steps: 23
# =======  EPISODE END  ================
#
# Episode 34: Reward = -16, Number of steps: 21
# =======  EPISODE END  ================
#
# Episode 35: Reward = -16, Number of steps: 21
# =======  EPISODE END  ================
#
# Episode 36: Reward = -16, Number of steps: 29
# =======  EPISODE END  ================
#
# Episode 37: Reward = -18, Number of steps: 26
# =======  EPISODE END  ================
#
# Episode 38: Reward = -16, Number of steps: 23
# =======  EPISODE END  ================
#
# Episode 39: Reward = -16, Number of steps: 27
# =======  EPISODE END  ================
#
# Episode 40: Reward = -20, Number of steps: 43
# =======  EPISODE END  ================
#
# Episode 41: Reward = -18, Number of steps: 30
# =======  EPISODE END  ================
#
# Episode 42: Reward = -16, Number of steps: 17
# =======  EPISODE END  ================
#
# Episode 43: Reward = -20, Number of steps: 35
# =======  EPISODE END  ================
#
# Episode 44: Reward = -16, Number of steps: 25
# =======  EPISODE END  ================
#
# Episode 45: Reward = 18, Number of steps: 28
# =======  EPISODE END  ================
#
# Episode 46: Reward = -18, Number of steps: 26
# =======  EPISODE END  ================
#
# Episode 47: Reward = -18, Number of steps: 30
# =======  EPISODE END  ================
#
# Episode 48: Reward = -18, Number of steps: 30
# =======  EPISODE END  ================
#
# Episode 49: Reward = -16, Number of steps: 19
# =======  EPISODE END  ================
#
# Episode 50: Reward = 18, Number of steps: 31
# =======  EPISODE END  ================
#
# Episode 51: Reward = -18, Number of steps: 30
# =======  EPISODE END  ================
#
# Episode 52: Reward = -16, Number of steps: 25
# =======  EPISODE END  ================
#
# Episode 53: Reward = -20, Number of steps: 35
# =======  EPISODE END  ================
#
# Episode 54: Reward = -20, Number of steps: 27
# =======  EPISODE END  ================
#
# Episode 55: Reward = -18, Number of steps: 34
# =======  EPISODE END  ================
#
# Episode 56: Reward = -16, Number of steps: 21
# =======  EPISODE END  ================
#
# Episode 57: Reward = -16, Number of steps: 17
# =======  EPISODE END  ================
#
# Episode 58: Reward = -18, Number of steps: 24
# =======  EPISODE END  ================
#
# Episode 59: Reward = -16, Number of steps: 15
# =======  EPISODE END  ================
#
# Episode 60: Reward = -16, Number of steps: 21
# =======  EPISODE END  ================
#
# Episode 61: Reward = -18, Number of steps: 28
# =======  EPISODE END  ================
#
# Episode 62: Reward = 20, Number of steps: 31
# =======  EPISODE END  ================
#
# Episode 63: Reward = -16, Number of steps: 31
# =======  EPISODE END  ================
#
# Episode 64: Reward = -20, Number of steps: 37
# =======  EPISODE END  ================
#
# Episode 65: Reward = -20, Number of steps: 31
# =======  EPISODE END  ================
#
# Episode 66: Reward = -18, Number of steps: 32
# =======  EPISODE END  ================
#
# Episode 67: Reward = -16, Number of steps: 17
# =======  EPISODE END  ================
#
# Episode 68: Reward = -20, Number of steps: 37
# =======  EPISODE END  ================
#
# Episode 69: Reward = 18, Number of steps: 32
# =======  EPISODE END  ================
#
# Episode 70: Reward = -16, Number of steps: 21
# =======  EPISODE END  ================
#
# Episode 71: Reward = -16, Number of steps: 23
# =======  EPISODE END  ================
#
# Episode 72: Reward = 20, Number of steps: 24
# =======  EPISODE END  ================
#
# Episode 73: Reward = -16, Number of steps: 23
# =======  EPISODE END  ================
#
# Episode 74: Reward = -18, Number of steps: 30
# =======  EPISODE END  ================
#
# Episode 75: Reward = 20, Number of steps: 39
# =======  EPISODE END  ================
#
# Episode 76: Reward = -20, Number of steps: 41
# =======  EPISODE END  ================
#
# Episode 77: Reward = -20, Number of steps: 33
# =======  EPISODE END  ================
#
# Episode 78: Reward = -16, Number of steps: 19
# =======  EPISODE END  ================
#
# Episode 79: Reward = -16, Number of steps: 21
# =======  EPISODE END  ================
#
# Episode 80: Reward = -18, Number of steps: 28
# =======  EPISODE END  ================
#
# Episode 81: Reward = -18, Number of steps: 34
# =======  EPISODE END  ================
#
# Episode 82: Reward = -16, Number of steps: 23
# =======  EPISODE END  ================
#
# Episode 83: Reward = -16, Number of steps: 17
# =======  EPISODE END  ================
#
# Episode 84: Reward = -20, Number of steps: 31
# =======  EPISODE END  ================
#
# Episode 85: Reward = -16, Number of steps: 21
# =======  EPISODE END  ================
#
# Episode 86: Reward = -18, Number of steps: 28
# =======  EPISODE END  ================
#
# Episode 87: Reward = -16, Number of steps: 25
# =======  EPISODE END  ================
#
# Episode 88: Reward = -16, Number of steps: 21
# =======  EPISODE END  ================
#
# Episode 89: Reward = -18, Number of steps: 36
# =======  EPISODE END  ================
#
# Episode 90: Reward = -16, Number of steps: 17
# =======  EPISODE END  ================
#
# Episode 91: Reward = -20, Number of steps: 33
# =======  EPISODE END  ================
#
# Episode 92: Reward = -16, Number of steps: 23
# =======  EPISODE END  ================
#
# Episode 93: Reward = -16, Number of steps: 25
# =======  EPISODE END  ================
#
# Episode 94: Reward = -16, Number of steps: 23
# =======  EPISODE END  ================
#
# Episode 95: Reward = -16, Number of steps: 21
# =======  EPISODE END  ================
#
# Episode 96: Reward = -20, Number of steps: 37
# =======  EPISODE END  ================
#
# Episode 97: Reward = 16, Number of steps: 25
# =======  EPISODE END  ================
#
# Episode 98: Reward = -18, Number of steps: 28
# =======  EPISODE END  ================
#
# Episode 99: Reward = -18, Number of steps: 28
# =======  EPISODE END  ================
#
# Episode 100: Reward = -20, Number of steps: 35
# =======  EPISODE END  ================
#
# Average Reward over 100 episodes: -12.5
# Good Win Rate: 0.87
# Evil Win Rate: 0.13
