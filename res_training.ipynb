# %%
from env.res_env import ResistanceEnv
import numpy as np
import os
from utils.buffer import SharedReplayBuffer
import numpy as np
from env.robot_1d import CorridorEnv, CorridorEnv_v2, CorridorFullyVisibleEnv, RandomRobotEnv, CorridorMultiAgentEnv
from runner.runner_res import RunnerMA
from alg.actor_critic import Actor, Critic

# %%
# Example configuration
class Args:
    def __init__(self):
        self.env_name = 'CorridorEnvMA'
        self.algorithm_name = 'PPO'
        self.experiment_name = 'corridor_experiment'
        self.use_centralized_V = True
        self.num_env_steps = 200000
        self.episode_length = 10000
        self.n_rollout_threads = 1
        self.use_linear_lr_decay = False
        self.hidden_size = 64
        self.gamma = .99
        self.gae_lambda = .95
        self._use_gae = True
        self.actor_lr = 7e-4
        self.critic_lr = 1e-3
        self.opti_eps=1e-5
        self.weight_decay=0
        self.gamma=0.99
        self.clip_param=0.2
        self.value_loss_coef=1
        self.entropy_coef=0.01
        self.ppo_epoch=10
        self.num_mini_batch=1
        self.huber_delta=10.0
        self.use_huber_loss=True
        self.use_clipped_value_loss=True
        self.gain = 0.01
        self.use_orthogonal = True
        self.use_feature_normalization = True
        self.use_ReLU = True
        self.layer_N = 1
        self.log_interval = 1000  # log every x steps
        
env = ResistanceEnv()

config = {
    'all_args': Args(),
    'env': env,
    'device': 'cpu',
    'num_agents': 3,
}
runner = RunnerMA(config)

# %%
runner.restore('save_dir')

# %%
runner.run(verbose=False)
# Out:
# 0 / 20 episodes, total number of timesteps: 10000/200000, FPS 1757.
# average episode rewards is 1694.9999332427979 (av.reward: 0.16949999332427979 * ep_length 10000)
#
# 1 / 20 episodes, total number of timesteps: 20000/200000, FPS 1774.
# average episode rewards is 1568.0000185966492 (av.reward: 0.15680000185966492 * ep_length 10000)
#
# 2 / 20 episodes, total number of timesteps: 30000/200000, FPS 1664.
# average episode rewards is 1818.9999461174011 (av.reward: 0.1818999946117401 * ep_length 10000)
#
# 3 / 20 episodes, total number of timesteps: 40000/200000, FPS 1618.
# average episode rewards is 1755.0000548362732 (av.reward: 0.17550000548362732 * ep_length 10000)
#
# 4 / 20 episodes, total number of timesteps: 50000/200000, FPS 1644.
# average episode rewards is 1711.0000550746918 (av.reward: 0.17110000550746918 * ep_length 10000)
#
# 5 / 20 episodes, total number of timesteps: 60000/200000, FPS 1619.
# average episode rewards is 1326.9999623298645 (av.reward: 0.13269999623298645 * ep_length 10000)
#
# 6 / 20 episodes, total number of timesteps: 70000/200000, FPS 1603.
# average episode rewards is 1059.9999874830246 (av.reward: 0.10599999874830246 * ep_length 10000)
#
# 7 / 20 episodes, total number of timesteps: 80000/200000, FPS 1590.
# average episode rewards is 1571.0000693798065 (av.reward: 0.15710000693798065 * ep_length 10000)
#
# 8 / 20 episodes, total number of timesteps: 90000/200000, FPS 1608.
# average episode rewards is 895.0000256299973 (av.reward: 0.08950000256299973 * ep_length 10000)
#
# 9 / 20 episodes, total number of timesteps: 100000/200000, FPS 1598.
# average episode rewards is 786.999985575676 (av.reward: 0.0786999985575676 * ep_length 10000)
#
# 10 / 20 episodes, total number of timesteps: 110000/200000, FPS 1585.
# average episode rewards is 684.0000301599503 (av.reward: 0.06840000301599503 * ep_length 10000)
#
# 11 / 20 episodes, total number of timesteps: 120000/200000, FPS 1600.
# average episode rewards is 966.000035405159 (av.reward: 0.0966000035405159 * ep_length 10000)
#
# 12 / 20 episodes, total number of timesteps: 130000/200000, FPS 1592.
# average episode rewards is 798.0000227689743 (av.reward: 0.07980000227689743 * ep_length 10000)
#
# 13 / 20 episodes, total number of timesteps: 140000/200000, FPS 1581.
# average episode rewards is 791.9999957084656 (av.reward: 0.07919999957084656 * ep_length 10000)
#
# 14 / 20 episodes, total number of timesteps: 150000/200000, FPS 1580.
# average episode rewards is 929.0000051259995 (av.reward: 0.09290000051259995 * ep_length 10000)
#
# 15 / 20 episodes, total number of timesteps: 160000/200000, FPS 1575.
# average episode rewards is 890.0000154972076 (av.reward: 0.08900000154972076 * ep_length 10000)
#
# 16 / 20 episodes, total number of timesteps: 170000/200000, FPS 1584.
# average episode rewards is 1340.000033378601 (av.reward: 0.1340000033378601 * ep_length 10000)
#
# 17 / 20 episodes, total number of timesteps: 180000/200000, FPS 1580.
# average episode rewards is 939.9999678134918 (av.reward: 0.09399999678134918 * ep_length 10000)
#
# 18 / 20 episodes, total number of timesteps: 190000/200000, FPS 1577.
# average episode rewards is 877.000018954277 (av.reward: 0.0877000018954277 * ep_length 10000)
#
# 19 / 20 episodes, total number of timesteps: 200000/200000, FPS 1574.
# average episode rewards is 1094.999983906746 (av.reward: 0.10949999839067459 * ep_length 10000)

# %%
#runner.trainer.policy

# %%
runner.save()

# %%
runner.eval(num_games=100, verbose=False)
# Out:
# Good players: ['player_5', 'player_4', 'player_1']
# Episode 1: Reward = 36, Number of steps: 17
# =======  EPISODE END  ================
#
# Good players: ['player_3', 'player_4', 'player_5']
# Episode 2: Reward = -33, Number of steps: 36
# =======  EPISODE END  ================
#
# Good players: ['player_4', 'player_3', 'player_2']
# Episode 3: Reward = 33, Number of steps: 36
# =======  EPISODE END  ================
#
# Good players: ['player_5', 'player_1', 'player_4']
# Episode 4: Reward = 36, Number of steps: 17
# =======  EPISODE END  ================
#
# Good players: ['player_3', 'player_5', 'player_2']
# Episode 5: Reward = 30, Number of steps: 31
# =======  EPISODE END  ================
#
# Good players: ['player_5', 'player_2', 'player_3']
# Episode 6: Reward = 36, Number of steps: 17
# =======  EPISODE END  ================
#
# Good players: ['player_5', 'player_1', 'player_4']
# Episode 7: Reward = 36, Number of steps: 17
# =======  EPISODE END  ================
#
# Good players: ['player_3', 'player_4', 'player_1']
# Episode 8: Reward = -33, Number of steps: 30
# =======  EPISODE END  ================
#
# Good players: ['player_1', 'player_3', 'player_2']
# Episode 9: Reward = 30, Number of steps: 29
# =======  EPISODE END  ================
#
# Good players: ['player_4', 'player_3', 'player_1']
# Episode 10: Reward = 36, Number of steps: 19
# =======  EPISODE END  ================
#
# Good players: ['player_4', 'player_2', 'player_5']
# Episode 11: Reward = 36, Number of steps: 17
# =======  EPISODE END  ================
#
# Good players: ['player_1', 'player_4', 'player_3']
# Episode 12: Reward = 30, Number of steps: 37
# =======  EPISODE END  ================
#
# Good players: ['player_1', 'player_4', 'player_5']
# Episode 13: Reward = -36, Number of steps: 17
# =======  EPISODE END  ================
#
# Good players: ['player_3', 'player_2', 'player_1']
# Episode 14: Reward = 30, Number of steps: 31
# =======  EPISODE END  ================
#
# Good players: ['player_5', 'player_1', 'player_3']
# Episode 15: Reward = 30, Number of steps: 31
# =======  EPISODE END  ================
#
# Good players: ['player_2', 'player_1', 'player_5']
# Episode 16: Reward = 33, Number of steps: 28
# =======  EPISODE END  ================
#
# Good players: ['player_5', 'player_2', 'player_4']
# Episode 17: Reward = -36, Number of steps: 25
# =======  EPISODE END  ================
#
# Good players: ['player_4', 'player_3', 'player_5']
# Episode 18: Reward = 36, Number of steps: 23
# =======  EPISODE END  ================
#
# Good players: ['player_1', 'player_4', 'player_2']
# Episode 19: Reward = 33, Number of steps: 22
# =======  EPISODE END  ================
#
# Good players: ['player_2', 'player_4', 'player_3']
# Episode 20: Reward = 33, Number of steps: 36
# =======  EPISODE END  ================
#
# Good players: ['player_2', 'player_3', 'player_4']
# Episode 21: Reward = -30, Number of steps: 37
# =======  EPISODE END  ================
#
# Good players: ['player_5', 'player_4', 'player_3']
# Episode 22: Reward = -36, Number of steps: 17
# =======  EPISODE END  ================
#
# Good players: ['player_1', 'player_3', 'player_2']
# Episode 23: Reward = 36, Number of steps: 25
# =======  EPISODE END  ================
#
# Good players: ['player_1', 'player_4', 'player_2']
# Episode 24: Reward = 30, Number of steps: 35
# =======  EPISODE END  ================
#
# Good players: ['player_3', 'player_4', 'player_2']
# Episode 25: Reward = 36, Number of steps: 27
# =======  EPISODE END  ================
#
# Good players: ['player_3', 'player_4', 'player_2']
# Episode 26: Reward = -30, Number of steps: 37
# =======  EPISODE END  ================
#
# Good players: ['player_5', 'player_1', 'player_2']
# Episode 27: Reward = 30, Number of steps: 31
# =======  EPISODE END  ================
#
# Good players: ['player_1', 'player_4', 'player_2']
# Episode 28: Reward = 30, Number of steps: 27
# =======  EPISODE END  ================
#
# Good players: ['player_1', 'player_2', 'player_3']
# Episode 29: Reward = 36, Number of steps: 25
# =======  EPISODE END  ================
#
# Good players: ['player_2', 'player_1', 'player_5']
# Episode 30: Reward = 30, Number of steps: 31
# =======  EPISODE END  ================
#
# Good players: ['player_3', 'player_4', 'player_1']
# Episode 31: Reward = -30, Number of steps: 31
# =======  EPISODE END  ================
#
# Good players: ['player_4', 'player_2', 'player_5']
# Episode 32: Reward = -33, Number of steps: 28
# =======  EPISODE END  ================
#
# Good players: ['player_5', 'player_3', 'player_4']
# Episode 33: Reward = 36, Number of steps: 23
# =======  EPISODE END  ================
#
# Good players: ['player_4', 'player_2', 'player_5']
# Episode 34: Reward = 33, Number of steps: 34
# =======  EPISODE END  ================
#
# Good players: ['player_2', 'player_1', 'player_5']
# Episode 35: Reward = 30, Number of steps: 31
# =======  EPISODE END  ================
#
# Good players: ['player_1', 'player_3', 'player_4']
# Episode 36: Reward = 33, Number of steps: 36
# =======  EPISODE END  ================
#
# Good players: ['player_2', 'player_4', 'player_5']
# Episode 37: Reward = 33, Number of steps: 34
# =======  EPISODE END  ================
#
# Good players: ['player_5', 'player_2', 'player_4']
# Episode 38: Reward = 30, Number of steps: 31
# =======  EPISODE END  ================
#
# Good players: ['player_2', 'player_4', 'player_5']
# Episode 39: Reward = 33, Number of steps: 34
# =======  EPISODE END  ================
#
# Good players: ['player_4', 'player_3', 'player_5']
# Episode 40: Reward = -36, Number of steps: 19
# =======  EPISODE END  ================
#
# Good players: ['player_3', 'player_2', 'player_4']
# Episode 41: Reward = 30, Number of steps: 33
# =======  EPISODE END  ================
#
# Good players: ['player_2', 'player_3', 'player_5']
# Episode 42: Reward = 30, Number of steps: 31
# =======  EPISODE END  ================
#
# Good players: ['player_2', 'player_3', 'player_1']
# Episode 43: Reward = 30, Number of steps: 31
# =======  EPISODE END  ================
#
# Good players: ['player_2', 'player_3', 'player_1']
# Episode 44: Reward = -36, Number of steps: 17
# =======  EPISODE END  ================
#
# Good players: ['player_3', 'player_4', 'player_1']
# Episode 45: Reward = -36, Number of steps: 21
# =======  EPISODE END  ================
#
# Good players: ['player_4', 'player_1', 'player_3']
# Episode 46: Reward = 33, Number of steps: 36
# =======  EPISODE END  ================
#
# Good players: ['player_5', 'player_1', 'player_4']
# Episode 47: Reward = -36, Number of steps: 17
# =======  EPISODE END  ================
#
# Good players: ['player_5', 'player_4', 'player_3']
# Episode 48: Reward = 33, Number of steps: 28
# =======  EPISODE END  ================
#
# Good players: ['player_3', 'player_5', 'player_2']
# Episode 49: Reward = 30, Number of steps: 31
# =======  EPISODE END  ================
#
# Good players: ['player_1', 'player_5', 'player_2']
# Episode 50: Reward = 30, Number of steps: 31
# =======  EPISODE END  ================
#
# Good players: ['player_1', 'player_2', 'player_5']
# Episode 51: Reward = 33, Number of steps: 28
# =======  EPISODE END  ================
#
# Good players: ['player_1', 'player_2', 'player_5']
# Episode 52: Reward = -36, Number of steps: 17
# =======  EPISODE END  ================
#
# Good players: ['player_4', 'player_1', 'player_3']
# Episode 53: Reward = 36, Number of steps: 19
# =======  EPISODE END  ================
#
# Good players: ['player_2', 'player_5', 'player_1']
# Episode 54: Reward = 30, Number of steps: 31
# =======  EPISODE END  ================
#
# Good players: ['player_4', 'player_5', 'player_2']
# Episode 55: Reward = 30, Number of steps: 31
# =======  EPISODE END  ================
#
# Good players: ['player_3', 'player_1', 'player_4']
# Episode 56: Reward = 33, Number of steps: 36
# =======  EPISODE END  ================
#
# Good players: ['player_3', 'player_4', 'player_5']
# Episode 57: Reward = -36, Number of steps: 19
# =======  EPISODE END  ================
#
# Good players: ['player_2', 'player_3', 'player_4']
# Episode 58: Reward = -30, Number of steps: 37
# =======  EPISODE END  ================
#
# Good players: ['player_5', 'player_2', 'player_1']
# Episode 59: Reward = -36, Number of steps: 17
# =======  EPISODE END  ================
#
# Good players: ['player_5', 'player_4', 'player_2']
# Episode 60: Reward = 30, Number of steps: 31
# =======  EPISODE END  ================
#
# Good players: ['player_3', 'player_5', 'player_2']
# Episode 61: Reward = 36, Number of steps: 17
# =======  EPISODE END  ================
#
# Good players: ['player_5', 'player_2', 'player_4']
# Episode 62: Reward = -36, Number of steps: 19
# =======  EPISODE END  ================
#
# Good players: ['player_3', 'player_4', 'player_1']
# Episode 63: Reward = -33, Number of steps: 30
# =======  EPISODE END  ================
#
# Good players: ['player_4', 'player_3', 'player_1']
# Episode 64: Reward = 30, Number of steps: 37
# =======  EPISODE END  ================
#
# Good players: ['player_1', 'player_2', 'player_3']
# Episode 65: Reward = 33, Number of steps: 28
# =======  EPISODE END  ================
#
# Good players: ['player_1', 'player_5', 'player_2']
# Episode 66: Reward = 30, Number of steps: 31
# =======  EPISODE END  ================
#
# Good players: ['player_4', 'player_1', 'player_2']
# Episode 67: Reward = 33, Number of steps: 22
# =======  EPISODE END  ================
#
# Good players: ['player_1', 'player_4', 'player_3']
# Episode 68: Reward = 33, Number of steps: 36
# =======  EPISODE END  ================
#
# Good players: ['player_4', 'player_2', 'player_1']
# Episode 69: Reward = -33, Number of steps: 26
# =======  EPISODE END  ================
#
# Good players: ['player_5', 'player_4', 'player_1']
# Episode 70: Reward = 30, Number of steps: 31
# =======  EPISODE END  ================
#
# Good players: ['player_5', 'player_4', 'player_2']
# Episode 71: Reward = -33, Number of steps: 28
# =======  EPISODE END  ================
#
# Good players: ['player_4', 'player_1', 'player_3']
# Episode 72: Reward = -36, Number of steps: 21
# =======  EPISODE END  ================
#
# Good players: ['player_5', 'player_2', 'player_1']
# Episode 73: Reward = 33, Number of steps: 28
# =======  EPISODE END  ================
#
# Good players: ['player_5', 'player_4', 'player_3']
# Episode 74: Reward = 36, Number of steps: 23
# =======  EPISODE END  ================
#
# Good players: ['player_5', 'player_2', 'player_1']
# Episode 75: Reward = -36, Number of steps: 15
# =======  EPISODE END  ================
#
# Good players: ['player_3', 'player_2', 'player_4']
# Episode 76: Reward = 30, Number of steps: 31
# =======  EPISODE END  ================
#
# Good players: ['player_4', 'player_3', 'player_5']
# Episode 77: Reward = -30, Number of steps: 39
# =======  EPISODE END  ================
#
# Good players: ['player_3', 'player_5', 'player_4']
# Episode 78: Reward = 36, Number of steps: 23
# =======  EPISODE END  ================
#
# Good players: ['player_4', 'player_1', 'player_3']
# Episode 79: Reward = 33, Number of steps: 36
# =======  EPISODE END  ================
#
# Good players: ['player_3', 'player_5', 'player_4']
# Episode 80: Reward = 36, Number of steps: 23
# =======  EPISODE END  ================
#
# Good players: ['player_3', 'player_1', 'player_5']
# Episode 81: Reward = -36, Number of steps: 17
# =======  EPISODE END  ================
#
# Good players: ['player_1', 'player_4', 'player_3']
# Episode 82: Reward = -36, Number of steps: 17
# =======  EPISODE END  ================
#
# Good players: ['player_1', 'player_5', 'player_2']
# Episode 83: Reward = 33, Number of steps: 26
# =======  EPISODE END  ================
#
# Good players: ['player_3', 'player_4', 'player_5']
# Episode 84: Reward = 33, Number of steps: 28
# =======  EPISODE END  ================
#
# Good players: ['player_1', 'player_3', 'player_5']
# Episode 85: Reward = 33, Number of steps: 30
# =======  EPISODE END  ================
#
# Good players: ['player_3', 'player_5', 'player_2']
# Episode 86: Reward = -30, Number of steps: 31
# =======  EPISODE END  ================
#
# Good players: ['player_4', 'player_3', 'player_1']
# Episode 87: Reward = 33, Number of steps: 36
# =======  EPISODE END  ================
#
# Good players: ['player_4', 'player_5', 'player_2']
# Episode 88: Reward = -30, Number of steps: 29
# =======  EPISODE END  ================
#
# Good players: ['player_1', 'player_4', 'player_2']
# Episode 89: Reward = 33, Number of steps: 26
# =======  EPISODE END  ================
#
# Good players: ['player_5', 'player_4', 'player_1']
# Episode 90: Reward = 33, Number of steps: 26
# =======  EPISODE END  ================
#
# Good players: ['player_2', 'player_5', 'player_4']
# Episode 91: Reward = 30, Number of steps: 31
# =======  EPISODE END  ================
#
# Good players: ['player_2', 'player_1', 'player_3']
# Episode 92: Reward = 36, Number of steps: 27
# =======  EPISODE END  ================
#
# Good players: ['player_2', 'player_1', 'player_5']
# Episode 93: Reward = 30, Number of steps: 31
# =======  EPISODE END  ================
#
# Good players: ['player_1', 'player_3', 'player_2']
# Episode 94: Reward = 36, Number of steps: 25
# =======  EPISODE END  ================
#
# Good players: ['player_5', 'player_3', 'player_2']
# Episode 95: Reward = 30, Number of steps: 31
# =======  EPISODE END  ================
#
# Good players: ['player_5', 'player_4', 'player_3']
# Episode 96: Reward = -36, Number of steps: 17
# =======  EPISODE END  ================
#
# Good players: ['player_4', 'player_5', 'player_3']
# Episode 97: Reward = 36, Number of steps: 23
# =======  EPISODE END  ================
#
# Good players: ['player_2', 'player_4', 'player_3']
# Episode 98: Reward = 33, Number of steps: 30
# =======  EPISODE END  ================
#
# Good players: ['player_5', 'player_3', 'player_2']
# Episode 99: Reward = 30, Number of steps: 31
# =======  EPISODE END  ================
#
# Good players: ['player_3', 'player_1', 'player_5']
# Episode 100: Reward = 33, Number of steps: 36
# =======  EPISODE END  ================
#
# Average Reward over 100 episodes: 13.35
# Win Rate: 0.71

# %% [markdown]
# 171-88
